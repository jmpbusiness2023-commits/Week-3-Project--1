# %%
import my_functions as mf
import pandas as pd

# Load the full movie DataFrame
df = pd.read_csv("full-df.csv")

# We will now call our cleaning function and visualize the cleaned data

df_cleaned = mf.clean_movie_data(df)
df_cleaned.head()
# Out:
# /Users/snow/Library/Python/3.9/lib/python/site-packages/urllib3/__init__.py:35: NotOpenSSLWarning: urllib3 v2 only supports OpenSSL 1.1.1+, currently the 'ssl' module is compiled with 'LibreSSL 2.8.3'. See: https://github.com/urllib3/urllib3/issues/3020
#   warnings.warn(
#               actors                                             awards  \
# 0  Robert Downey Jr.  Nominated for 1 Oscar. 70 wins & 132 nominatio...
# 1    Sam Worthington       Won 1 Oscar. 73 wins & 152 nominations total
# 2         Tom Cruise                       6 wins & 3 nominations total
# 3        Johnny Depp                      3 wins & 31 nominations total
# 4  Robert Downey Jr.                      8 wins & 52 nominations total
#
#     box_office                               country  \
# 0  858373000.0                         United States
# 1  684075767.0                         United States
# 2  197413515.0         United Kingdom, United States
# ...

# %%
df_cleaned.isna().sum()
# Out:
# actors                372
# awards               1251
# box_office           1347
# country               350
# director              466
# domestic_gross          0
# genre                 351
# language              363
# meta_score           1277
# plot                  407
# production_budget       0
# rated                 611
# release_date          147
# runtime               417
# title                   0
# worldwide_gross         0
# writer                474
# imdb_id               340
# imdb_rating           441
# imdb_votes            421
# dtype: int64

# %% [markdown]
# #### Global Visualization of the Dataset.

# %%
mf.visualize_movies(df_cleaned)
# Out:
# /Users/snow/Documents/IRON HACK COURSE/Week 3/Project/Week-3-Project--1/my_functions.py:151: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# /Users/snow/Documents/IRON HACK COURSE/Week 3/Project/Week-3-Project--1/my_functions.py:161: UserWarning: Glyph 21738 (\N{CJK UNIFIED IDEOGRAPH-54EA}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/snow/Documents/IRON HACK COURSE/Week 3/Project/Week-3-Project--1/my_functions.py:161: UserWarning: Glyph 21522 (\N{CJK UNIFIED IDEOGRAPH-5412}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# /Users/snow/Documents/IRON HACK COURSE/Week 3/Project/Week-3-Project--1/my_functions.py:161: UserWarning: Glyph 20043 (\N{CJK UNIFIED IDEOGRAPH-4E4B}) missing from font(s) DejaVu Sans.
#   plt.tight_layout()
# ...

# %% [markdown]
# #### Hypothesis 1 : Movies with lower production budgets can still achieve high IMDb ratings

# %%
# Lets make a copy of the cleaned dataframe to perform further analysis
movie_df_cleaned = df_cleaned.copy()

# %%
genre_counts = movie_df_cleaned["genre"].value_counts()
movie_df_cleaned = movie_df_cleaned[movie_df_cleaned["genre"].isin(genre_counts[genre_counts >= 51].index)]
movie_df_cleaned["genre"].value_counts()
# Out:
# genre
# Comedy         1498
# Action         1483
# Drama          1110
# Crime           394
# Adventure       389
# Biography       384
# Animation       352
# Horror          320
# Documentary     174
# Name: count, dtype: int64

# %%
mf.visualize_hypothesis_1(movie_df_cleaned)
# Out:
#                 actors                                             awards  \
# 6524               NaN                                                NaN
# 6447       Henry Fonda  Nominated for 3 Oscars. 16 wins & 12 nominatio...
# 6229      Jared Balsky                                                NaN
# 5219    Jack Nicholson       Won 5 Oscars. 38 wins & 15 nominations total
# 6341    Toshirô Mifune  Nominated for 2 Oscars. 5 wins & 9 nominations...
# 6715       Tony Cazeau                                                NaN
# 5450     James Stewart  Nominated for 5 Oscars. 11 wins & 7 nomination...
# 5952   Charles Chaplin                        6 wins & 1 nomination total
# 5065       Henry Fonda                       6 wins & 5 nominations total
# 6499  Sarah Lancashire         Won 6 BAFTA 36 wins & 35 nominations total
#
#        box_office               country                       director  \
# 6524          NaN         United States  Seth Camillo, Barbara Camillo
# ...

# %% [markdown]
# #### Hypothesis 2 : Are Hight IMDB Rated Movies More Profitable?

# %%
mf.visualize_hypothesis_2(movie_df_cleaned)
# Out:
# 📈 Correlation IMDb Rating ↔ Profit : 0.22
#                 actors                                             awards  \
# 34     Sam Worthington      Won 3 Oscars. 91 wins & 131 nominations total
# 0    Robert Downey Jr.  Nominated for 1 Oscar. 70 wins & 132 nominatio...
# 61   Leonardo DiCaprio     Won 11 Oscars. 126 wins & 84 nominations total
# 1      Sam Worthington       Won 1 Oscar. 73 wins & 152 nominations total
# 735         Yanting Lü                       7 wins & 2 nominations total
# 7    Robert Downey Jr.  Nominated for 1 Oscar. 48 wins & 80 nomination...
# 59         Tom Holland  Nominated for 1 Oscar. 35 wins & 71 nomination...
# 956       Daisy Ridley  Nominated for 5 Oscars. 64 wins & 140 nominati...
# 62         Amy Poehler  Nominated for 1 Oscar. 7 wins & 106 nomination...
# 18   Matthew Broderick       Won 2 Oscars. 43 wins & 35 nominations total
#
#       box_office                        country                   director  \
# ...

# %% [markdown]
# ### Hypothesis 3 : Some genre are more protifable than others

# %%
mf.visualize_hypothesis_3(movie_df_cleaned)
# Out:
# 📊 Average ROI and IMDb Rating by Genre:
# /Users/snow/Documents/IRON HACK COURSE/Week 3/Project/Week-3-Project--1/my_functions.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset["profit"] = subset["worldwide_gross"] - subset["production_budget"]
# /Users/snow/Documents/IRON HACK COURSE/Week 3/Project/Week-3-Project--1/my_functions.py:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['roi'] = (subset['profit']) / subset['production_budget']
# ...

# %%
mf.visualize_hypothesis_3(movie_df_cleaned)
# Out:
# 📊 Average ROI and IMDb Rating by Genre:
# /Users/snow/Documents/IRON HACK COURSE/Week 3/Project/Week-3-Project--1/my_functions.py:261: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset["profit"] = subset["worldwide_gross"] - subset["production_budget"]
# /Users/snow/Documents/IRON HACK COURSE/Week 3/Project/Week-3-Project--1/my_functions.py:262: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   subset['roi'] = (subset['profit']) / subset['production_budget']
# ...
